# %%
import numpy as np
import matplotlib.pyplot as plt

with open('data.csv', 'r') as f:
  data = f.readlines()

x = []
y = []

for i in range(1, len(data)):
  row = data[i].strip().split(';')
  x.append(float(row[0]))
  y.append(float(row[1]))
print(x)
print(y)

plt.figure(figsize=(8, 5))
plt.plot(x, y)
plt.title('Исходные данные')
plt.legend()
plt.grid()
plt.show()

n = len(y)
L = 3
z = [0] * n
for k in range(L, n - L):
  z[k] = np.mean(y[k - L:k + L + 1])

plt.figure(figsize=(8, 5))
plt.plot(x, y, label='Исходный')
plt.plot(x, z, label='Скользящее среднее L = 3')
plt.title('Скользящее среднее')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid()
plt.show()

another_L = [2, 4]

for L in another_L:
    z = [0] * n
    for k in range(L, n - L):
        z[k] = np.mean(y[k - L:k + L + 1])

    plt.figure(figsize=(8, 5))
    plt.plot(x, y, label='Исходный ряд')
    plt.plot(x, z, label=f'Скользящее среднее L = {L}')
    plt.title('Скользящее среднее')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.grid()
    plt.show()

a = 0.1
b = 0.9

t0 = [y[0]]
for k in range(1, N):
  t = a * y[k] + b * t0[k - 1]
  t0.append(t)

plt.figure(figsize=(8, 5))
plt.plot(x, y, label='Исходный ряд')
plt.plot(x, t0, label=f'Экспоненциальное сглаживание a = 0.1 b = 0.9')
plt.title(f'Экспоненциальное сглаживание')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid()
plt.show()

another_a = [0.2, 0.3, 0.4]

for a in another_a:
  b = 1 - a

  t0 = [y[0]]

  for k in range(1, N):
    t = a * y[k] + b * t0[k - 1]
    t0.append(t)

  plt.figure(figsize=(8, 5))
  plt.plot(x, y, label='Исходный ряд')
  plt.plot(x, t0, label=f'Экспоненциальное сглаживание a = {a} b = {b})')
  plt.title('Экспоненциальное сглаживание')
  plt.xlabel('x')
  plt.ylabel('y')
  plt.legend()
  plt.grid()
  plt.show()
# Out:
# [0.0, 0.031415927, 0.062831853, 0.09424778, 0.125663706, 0.157079633, 0.188495559, 0.219911486, 0.251327412, 0.282743339, 0.314159265, 0.345575192, 0.376991118, 0.408407045, 0.439822972, 0.471238898, 0.502654825, 0.534070751, 0.565486678, 0.596902604, 0.628318531, 0.659734457, 0.691150384, 0.72256631, 0.753982237, 0.785398163, 0.81681409, 0.848230016, 0.879645943, 0.91106187, 0.942477796, 0.973893723, 1.005309649, 1.036725576, 1.068141502, 1.099557429, 1.130973355, 1.162389282, 1.193805208, 1.225221135, 1.256637061, 1.288052988, 1.319468915, 1.350884841, 1.382300768, 1.413716694, 1.445132621, 1.476548547, 1.507964474, 1.5393804, 1.570796327, 1.602212253, 1.63362818, 1.665044106, 1.696460033, 1.727875959, 1.759291886, 1.790707813, 1.822123739, 1.853539666, 1.884955592, 1.916371519, 1.947787445, 1.979203372, 2.010619298, 2.042035225, 2.073451151, 2.104867078, 2.136283004, 2.167698931, 2.199114858, 2.230530784, 2.261946711, 2.293362637, 2.324778564, 2.35619449, 2.387610417, 2.419026343,
# ...
